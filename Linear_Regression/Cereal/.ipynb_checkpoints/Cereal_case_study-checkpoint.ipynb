# %% [markdown]
# # Data Description
#
# ### Context
# * If you like to eat cereal, do yourself a favor and avoid this dataset at all costs. After seeing these data it will never be the same for me to eat Fruity Pebbles again.
#
# ### Content
# #### Fields in the dataset:
#
#     * Name: Name of cereal
#     * mfr: Manufacturer of cereal
#     * A = American Home Food Products;
#     * G = General Mills
#     * K = Kelloggs
#     * N = Nabisco
#     * P = Post
#     * Q = Quaker Oats
#     * R = Ralston Purina
#
#
# #### type:
#     * cold
#     * hot
# * calories: calories per serving
# * protein: grams of protein
# * fat: grams of fat
# * sodium: milligrams of sodium
# * fiber: grams of dietary fiber
# * carbo: grams of complex carbohydrates
# * sugars: grams of sugars
# * potass: milligrams of potassium
# * vitamins: vitamins and minerals - 0, 25, or 100, indicating the typical percentage of FDA recommended
# * shelf: display shelf (1, 2, or 3, counting from the floor)
# * weight: weight in ounces of one serving
# * cups: number of cups in one serving
# * rating: a rating of the cereals (Possibly from Consumer Reports?)
#
#
# ### Acknowledgements
# * These datasets have been gathered and cleaned up by Petra Isenberg, Pierre Dragicevic and Yvonne Jansen. The original source can be found here
#
# * This dataset has been converted to CSV
#
# ### Inspiration
# * Eat too much sugary cereal? Ruin your appetite with this dataset!

# %%
#### For Linear Algebra
import numpy as np
#### For Data Processing/manipulation
import pandas as pd
#### For Data visualization
import seaborn as se
import matplotlib.pyplot as mlt

# %%
data = pd.read_csv("cereal.csv")
data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df_dp[df_dp["AVG_STATIC_PREASSURE"] < 0]
prev = 0
for i in df_dp["AVG_STATIC_PREASSURE"]:
    if i < 0:
        df_dp["AVG_STATIC_PREASSURE"].replace(to_replace=i,value=prev,inplace=True)
        prev = i
    else:
        prev = i
df_dp[df_dp["AVG_STATIC_PREASSURE"] < 0]
# Out:
# Empty DataFrame
# Columns: [name, mfr, type, calories, protein, fat, sodium, fiber, carbo, sugars, potass, vitamins, shelf, weight, cups, rating]
# Index: []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %% [markdown]
# ##### name , mfr and type are in string formet other data is having neumarical values.

# %%
data.describe(include="all")
# Out:
#             name  mfr type    calories    protein        fat      sodium  \
# count         77   77   77   77.000000  77.000000  77.000000   77.000000
# unique        77    7    2         NaN        NaN        NaN         NaN
# top     Clusters    K    C         NaN        NaN        NaN         NaN
# freq           1   23   74         NaN        NaN        NaN         NaN
# mean         NaN  NaN  NaN  106.883117   2.545455   1.012987  159.675325
# std          NaN  NaN  NaN   19.484119   1.094790   1.006473   83.832295
# min          NaN  NaN  NaN   50.000000   1.000000   0.000000    0.000000
# 25%          NaN  NaN  NaN  100.000000   2.000000   0.000000  130.000000
# 50%          NaN  NaN  NaN  110.000000   3.000000   1.000000  180.000000
# 75%          NaN  NaN  NaN  110.000000   3.000000   2.000000  210.000000
# max          NaN  NaN  NaN  160.000000   6.000000   5.000000  320.000000
#
#             fiber      carbo     sugars      potass    vitamins      shelf  \
# ...

# %% [markdown]
# ##### Stastical Overrview of data.

# %%
print(data.shape)
data.isnull().sum()
# Out:
# (77, 16)
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %% [markdown]
# * Data has 16 column's but only 77 rows.
# * No null Values

# %%
mlt.figure(figsize=(16, 8))


mlt.subplot(1,2,1)
mlt.hist(data['sugars'])
mlt.title('sugars')


mlt.subplot(1,2,2)
se.distplot(data['vitamins'])
mlt.title('vitamins')

mlt.show()

# %% [markdown]
# ### Observation:-
#     * Sugars have an large distubution frpm 0 to 14.
#     * vitamins majorly distubuted fom 20 - 40.

# %%
mlt.figure(figsize=(15,5))
se.heatmap(data.corr(),annot=True)
mlt.show()

# %% [markdown]
# #### Traget=> rating
#
# * calories(-0.69) , protin(0.47),fat(-0.4),fiber(0.58),sugars(-0.76) are highely corelated with rating.

# %%
data.replace('N','Nabisco',inplace=True)
data.replace('Q','Quaker Oats',inplace=True)
data.replace('K','Kelloggs',inplace=True)
data.replace('R','Raslston Purina',inplace=True)
data.replace('G','General Mills',inplace=True)
data.replace('P','Post',inplace=True)
data.replace('A','American Home Foods Products',inplace=True)
data
# Out:
#                          name              mfr type  calories  protein  fat  \
# 0                   100% Bran          Nabisco    C        70        4    1
# 1           100% Natural Bran      Quaker Oats    C       120        3    5
# 2                    All-Bran         Kelloggs    C        70        4    1
# 3   All-Bran with Extra Fiber         Kelloggs    C        50        4    0
# 4              Almond Delight  Raslston Purina    C       110        2    2
# ..                        ...              ...  ...       ...      ...  ...
# 72                    Triples    General Mills    C       110        2    1
# 73                       Trix    General Mills    C       110        1    1
# 74                 Wheat Chex  Raslston Purina    C       100        3    1
# 75                   Wheaties    General Mills    C       100        3    1
# 76        Wheaties Honey Gold    General Mills    C       110        2    1
#
# ...

# %%
se.countplot(y=data['mfr'])
mlt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['mfr'] = le.fit_transform(data['mfr'])
data
# Out:
#                          name  mfr type  calories  protein  fat  sodium  \
# 0                   100% Bran    3    C        70        4    1     130
# 1           100% Natural Bran    5    C       120        3    5      15
# 2                    All-Bran    2    C        70        4    1     260
# 3   All-Bran with Extra Fiber    2    C        50        4    0     140
# 4              Almond Delight    6    C       110        2    2     200
# ..                        ...  ...  ...       ...      ...  ...     ...
# 72                    Triples    1    C       110        2    1     250
# 73                       Trix    1    C       110        1    1     140
# 74                 Wheat Chex    6    C       100        3    1     230
# 75                   Wheaties    1    C       100        3    1     200
# 76        Wheaties Honey Gold    1    C       110        2    1     200
#
#     fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
x=data[["calories","sugars","protein","carbo","fiber","mfr"]]
y=data["rating"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=15)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.intercept_
# Out:
# 61.71045498990825

# %%
y_predict = lr.predict(x_test)
y_predict
# Out:
# array([47.60317761, 29.96454304, 57.31621464, 47.58537562, 44.49298805,
#        42.05749575, 24.11883836, 30.09578957, 35.38424631, 32.22870468,
#        22.81318504, 29.52553587, 94.02435863, 51.2258391 , 54.8850996 ,
#        29.59103677, 27.91007308, 53.08378926, 24.11883836, 52.61476492])

# %%
mlt.scatter(y_predict,y_test)
mlt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,max_error
print("mean_squared_error: ",mean_squared_error(y_test,y_predict))
print("mean_absolute_error: ",mean_absolute_error(y_test,y_predict))
print("root_mean_squared_error: ",mean_squared_error(y_test,y_predict,squared=False))
# Out:
# mean_squared_error:  22.239038844369958
# mean_absolute_error:  3.531762183609692
# root_mean_squared_error:  4.715828542723957

# %%
print("max Error: ",max_error(y_test,y_predict))
print("R2_Score: ",r2_score(y_test,y_predict))
# Out:
# max Error:  9.722299100364573
# R2_Score:  0.9214469566836454

# %%
residual_test = y_test - y_predict

se.distplot(residual_test)
mlt.show()

# %%
se.boxplot(residual_test)
mlt.show()
